# %%
import numpy as np
import pandas as pd
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',160)
# %matplotlib inline

# %%
df = pd.read_excel('C:\PM-JAY\Daily_work\Diseases_analysis\ACCELERATED_HYPERTENSION.xlsx')

# %%
df.head(2)
# Out:
#   key_app_stateientno_npt patient_no_npt             case_no_npt  \
# 0            TMS_16_27768          27768  CASE/HS16002022/S77829
# 1            TMS_16_27809          27809  CASE/HS16008001/S77974
#
#               case_no_pat card_no_npt  age_npt gender_npt  \
# 0  CASE/HS16002022/S77829   PVGV1UYA3       55       MALE
# 1  CASE/HS16008001/S77974   P1Q5WC5ZE       39     FEMALE
#
#   patient_source_id_pat        patient_family_id_pat  state_code_npt  \
# 0                     S  16S160200600020000001200041              16
# 1                     S  16S160400070160005001200054              16
#
#    district_code_npt  hosp_state_code_npt  hosp_district_code_npt  \
# 0              271.0                   16                     271
# 1              655.0                   16                     655
#
#   hosp_disp_code_npt                 hospital_name_npt hosp_type_npt  \
# 0         HS16002022  Rajnagar Community Health Centre        Public
# 1         HS16008001          Kumarghat Rural Hospital        Public
#
#    hosp_grade_npt speciality_code_npt proc_code_npt workflow_upd_dt_npt  \
# 0             NaN                  M1       M100007 2020-09-07 14:00:45
# 1             NaN                  M1       M100007 2019-08-14 15:34:24
#
#    current_workflow_id_npt       ip_reg_dt_npt preauth_init_dt_npt  \
# 0                    664.0 2019-08-05 19:55:33 2019-08-05 19:55:33
# 1                    664.0 2019-08-06 11:18:42 2019-08-06 11:18:42
#
#   preauth_cancel_dt_npt preauth_rej_dt_pat  preauth_app_dt_npt  \
# 0                   NaT                NaT 2019-08-05 19:55:33
# 1                   NaT                NaT 2019-08-06 11:18:42
#
#   admission_dt_pat surgery_dt_npt death_dt_npt discharge_dt_npt  \
# 0       2019-08-04     2019-08-04          NaT       2019-08-05
# 1       2019-08-06     2019-08-06          NaT       2019-08-07
#
#   claim_submitted_dt_npt  claim_apprv_dt_pat claim_rej_dt_pat  \
# 0    2019-08-05 19:58:44 2019-08-10 10:54:40              NaT
# 1    2019-08-07 13:04:55 2019-08-11 11:09:41              NaT
#
#      claim_paid_dt_npt  preauth_pkg_amnt_npt  enh_app_amt_pat  \
# 0  2019-08-14 00:00:00                1800.0              NaN
# 1  2019-08-14 00:00:00                1800.0              NaN
#
#    preauth_app_amt_npt  claim_amt_npt  total_claim_aprv_amt_npt  \
# 0               1800.0         1800.0                    1800.0
# 1               1800.0         1800.0                    1800.0
#
#    total_claim_paid_amt_npt  portability_npt application_type_npt  \
# 0                    1800.0              0.0                  TMS
# 1                    1800.0              0.0                  TMS
#
#            crt_dt_npt      lst_upd_dt_npt      crt_dt_dwh_npt  \
# 0 2019-08-05 19:48:09 2020-09-07 14:00:45 2023-05-19 09:00:18
# 1 2019-08-06 11:15:40 2019-08-14 15:34:24 2023-05-19 09:00:18
#
#    lst_upd_dt_dwh_npt crt_usr_npt non_pmjay_npt policy_year_npt  \
# 0 2023-05-19 09:00:18      USER56             N             PS1
# 1 2023-05-19 09:00:18     USER100             N             PS1
#
#   patient_no_pat  ...  proc_value_2 proc_spec_2  proc_spec_name_2 proc_code_3  \
# 0          27768  ...           NaN         NaN               NaN         NaN
# 1          27809  ...           NaN         NaN               NaN         NaN
#
#   proc_name_3  proc_value_3  proc_spec_3  proc_spec_name_3 proc_code_4  \
# 0         NaN           NaN          NaN               NaN         NaN
# 1         NaN           NaN          NaN               NaN         NaN
#
#   proc_name_4 proc_value_4 proc_spec_4  proc_spec_name_4  proc_code_5  \
# 0         NaN          NaN         NaN               NaN          NaN
# 1         NaN          NaN         NaN               NaN          NaN
#
#   proc_name_5 proc_value_5 proc_spec_5 proc_spec_name_5 proc_code_6  \
# 0         NaN          NaN         NaN              NaN         NaN
# 1         NaN          NaN         NaN              NaN         NaN
#
#   proc_name_6 proc_value_6 proc_spec_6 proc_spec_name_6 proc_code_7  \
# 0         NaN          NaN         NaN              NaN         NaN
# 1         NaN          NaN         NaN              NaN         NaN
#
#   proc_name_7 proc_value_7 proc_spec_7 proc_spec_name_7 proc_code_8  \
# 0         NaN          NaN         NaN              NaN         NaN
# 1         NaN          NaN         NaN              NaN         NaN
#
#   proc_name_8 proc_value_8 proc_spec_8 proc_spec_name_8 proc_code_9  \
# 0         NaN          NaN         NaN              NaN         NaN
# 1         NaN          NaN         NaN              NaN         NaN
#
#   proc_name_9 proc_value_9 proc_spec_9 proc_spec_name_9 proc_code_10  \
# 0         NaN          NaN         NaN              NaN          NaN
# 1         NaN          NaN         NaN              NaN          NaN
#
#   proc_name_10 proc_value_10 proc_spec_10 proc_spec_name_10 proc_code_11  \
# 0          NaN           NaN          NaN               NaN          NaN
# 1          NaN           NaN          NaN               NaN          NaN
#
#   proc_name_11 proc_value_11 proc_spec_11 proc_spec_name_11  scheme_id_npt  \
# 0          NaN           NaN          NaN               NaN              S
# 1          NaN           NaN          NaN               NaN              S
#
#               load_dt
# 0 2023-11-28 08:12:50
# 1 2023-11-28 08:12:50
#
# [2 rows x 160 columns]
